# %%
import pandas as pd
import numpy as np
prog_lang = {"clojure": [".clj", ".cljs", ".edn", ".clojure"],
             "haskell" : [".hs", ".lhs", ".ghc"],
             "java": [".java", ".jar"],
             "javascript": [".js", ".javascript"],
             "ocaml": [".ml"],
             "perl" : [".pl", ".pm", ".t", ".pod"],
             "php" : [".php", ".phtml", ".php4", ".php3", ".php5", ".phps"],
             "python" : [".py", ".py", ".pyw", ".pyc", ".pyo", ".pyd", ".python3"],
             "ruby" : ["rb", ".rbw"],
             "scala" : [".scala"],
             "scheme" : [".scm", ".ss", ".racket"],
             "tcl" : [".tcl"]
             }

extensions = (".clj", ".cljs", ".edn", ".clojure",
             ".hs", ".lhs", ".ghc",".java", ".jar",
             ".js", ".javascript", ".ml", ".pl",
             ".pm", ".t", ".pod", ".php", ".phtml",
             ".php4", ".php3", ".php5", ".phps",
             ".py", ".pyw", ".pyc", ".pyo", ".pyd",
             ".python3", "rb", ".rbw", ".scala",
             ".scm", ".ss", ".racket", ".tcl")
import os
def get_files(dir_path):
    text_list = []
    ext_list = []
    for subdir, dirs, files in os.walk(dir_path):
        for name in files:
            if name.endswith((extensions)):
                ext_list.append(grab_extension(name))
                with open(os.path.join(subdir, name)) as f:
                    text_list.append(f.read())
    return pd.DataFrame({"Language": ext_list, "Text" : text_list})


def grab_extension(file):
    for lang in prog_lang.keys():
        for ext in prog_lang[lang]:
            if file.endswith(ext):
                return lang

# %%
lists = get_files("training/benchmarks/benchmarksgame/bench/")

# %%
lists
# Out:
#        Language                                               Text
# 0       clojure  ;; The Computer Language Benchmarks Game\n;; h...
# 1       clojure  ;; The Computer Language Benchmarks Game\n;; h...
# 2       clojure  ;; The Computer Language Benchmarks Game\n;; h...
# 3       haskell  --\n-- The Computer Language Benchmarks Game\n...
# 4       haskell  --\n-- The Computer Language Benchmarks Game\n...
# 5       haskell  --\n-- The Computer Language Benchmarks Game\n...
# 6          java  /* The Computer Language Benchmarks Game\n   h...
# 7          java  /* The Computer Language Benchmarks Game\n   h...
# 8          java  /* The Computer Language Benchmarks Game\n * h...
# 9    javascript  /* The Computer Language Benchmarks Game\n   h...
# 10          php  <?php \n/* The Computer Language Benchmarks Ga...
# 11          php  <?php \n/* The Computer Language Benchmarks Ga...
# 12          php  <?php \n/* The Computer Language Benchmarks Ga...
# 13          php  <?php \n/* The Computer Language Benchmarks Ga...
# 14       python  # The Computer Language Benchmarks Game\n# htt...
# 15       scheme  #lang racket/base\n\n;;; The Computer Language...
# 16       scheme  #lang racket/base\n\n;;; The Computer Language...
# 17       scheme  #lang racket/base\n\n;;; The Computer Language...
# 18        scala  /* The Computer Language Benchmarks Game\n   h...
# 19        scala  /* The Computer Language Benchmarks Game\n   h...
# 20        scala  /* The Computer Language Benchmarks Game\n   h...
# 21      clojure  ;; The Computer Language Benchmarks Game\n;; h...
# 22      clojure  ;; The Computer Language Benchmarks Game\n;; h...
# 23      haskell  --\n-- The Computer Language Benchmarks Game\n...
# 24         java  /* The Computer Language Benchmarks Game\n   h...
# 25        scala  /* The Computer Language Benchmarks Game\n   h...
# 26      clojure  ; The Computer Language Benchmarks Game\n; htt...
# 27      haskell  {- The Computer Language Benchmarks Game\n   h...
# 28      haskell  {- The Computer Language Benchmarks Game\n   h...
# 29         java  /* The Computer Language Benchmarks Game\n   h...
# ..          ...                                                ...
# 254  javascript  // The Computer Language Benchmarks Game\n// h...
# 255  javascript  // The Computer Language Benchmarks Game\n// h...
# 256  javascript  // The Computer Language Benchmarks Game\n// h...
# 257         php  <? \n/* The Computer Language Benchmarks Game\...
# 258         php  <? \n/* \n   The Computer Language Benchmarks ...
# 259      python  # The Computer Language Benchmarks Game\n# htt...
# 260      python  \n# The Computer Language Benchmarks Game\n# h...
# 261      python  # The Computer Language Benchmarks Game\n# htt...
# 262      python  # The Computer Language Benchmarks Game\n# htt...
# 263      python  # The Computer Language Benchmarks Game\n# htt...
# 264      scheme  #lang racket/base\n\n;;; The Computer Language...
# 265      scheme  #lang racket/base\n\n;;; The Computer Language...
# 266      scheme  #lang racket/base\n;; The Computer Language Be...
# 267       scala  /* The Computer Language Benchmarks Game\n   h...
# 268       scala  /* The Computer Language Benchmarks Game\n   h...
# 269       scala  /* The Computer Language Benchmarks Game\n   h...
# 270       scala  /* The Computer Language Benchmarks Game\n   h...
# 271     clojure  ;; The Computer Language Benchmarks Game\n;; h...
# 272     clojure  ;; The Computer Language Benchmarks Game\n;; h...
# 273     haskell  -- The Computer Language Benchmarks Game\n-- h...
# 274        java  /**\n * The Computer Language Benchmarks Game\...
# 275        java  /**\n * The Computer Language Benchmarks Game\...
# 276        java  /**\n * The Computer Language Benchmarks Game\...
# 277        java  /**\n * The Computer Language Benchmarks Game\...
# 278        java  /**\n * The Computer Language Benchmarks Game\...
# 279        java  /**\n * The Computer Language Benchmarks Game\...
# 280      python  # The Computer Language Benchmarks Game\n# htt...
# 281      python  # The Computer Language Benchmarks Game\n# htt...
# 282      scheme  #lang racket/base\n\n;;; The Computer Language...
# 283       scala  /* The Computer Language Benchmarks Game\n   h...
#
# [284 rows x 2 columns]

# %%
from textblob import TextBlob

df["Textblob"] = df.Text.apply((lambda x: TextBlob(x).words))
df["Textblob letters"] = df.Text.apply((lambda x: TextBlob(x)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8ede04d0ac1d> in <module>()
#       1 from textblob import TextBlob
#       2
# ----> 3 df["Textblob"] = df.Text.apply((lambda x: TextBlob(x).words))
#       4 df["Textblob letters"] = df.Text.apply((lambda x: TextBlob(x)))
#
# NameError: name 'df' is not defined

# %%
df

# %%
from sklearn.cross_validation import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB

from sklearn import metrics
from sklearn.cross_validation import cross_val_score
from sklearn.ensemble import RandomForestClassifier 
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.externals.six import StringIO  
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.grid_search import GridSearchCV
from sklearn.cross_validation import StratifiedKFold, cross_val_score, train_test_split 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.learning_curve import learning_curve
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing

# %%
bow_transformer = CountVectorizer(lambda x: TextBlob(x).words).fit(df['Text'])


messages_bow = bow_transformer.transform(df['Text'])
tfidf_transformer = TfidfTransformer().fit(messages_bow)

messages_tfidf = tfidf_transformer.transform(messages_bow)
print(messages_tfidf.shape)

languages = df[["Language"]]
# Out:
# (284, 5544)

# %%
attributes_train, attributes_test, class_train, class_test = \
train_test_split(messages_tfidf.toarray(), languages, test_size=0.4, random_state=0)


from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier = classifier.fit(attributes_train, class_train)
predicted = classifier.predict(attributes_test)

from sklearn import metrics
print(metrics.classification_report(class_test, predicted))
print(metrics.confusion_matrix(class_test, predicted))
print(metrics.f1_score(class_test, predicted))

from sklearn.cross_validation import cross_val_score

scores = cross_val_score(classifier, spam_base, spam_target, cv=5)
# Out:
#              precision    recall  f1-score   support
#
#     clojure       0.45      0.71      0.56        14
#     haskell       0.71      0.86      0.77        14
#        java       0.74      0.67      0.70        21
#  javascript       1.00      0.60      0.75        10
#         php       0.78      1.00      0.88         7
#      python       0.73      0.69      0.71        16
#       scala       0.69      0.50      0.58        18
#      scheme       0.85      0.79      0.81        14
#
# avg / total       0.73      0.70      0.70       114
#
# [[10  0  2  0  1  0  0  1]
#  [ 1 12  1  0  0  0  0  0]
#  [ 2  1 14  0  1  2  1  0]
#  [ 1  0  0  6  0  2  1  0]
#  [ 0  0  0  0  7  0  0  0]
#  [ 0  1  1  0  0 11  2  1]
#  [ 7  1  1  0  0  0  9  0]
#  [ 1  2  0  0  0  0  0 11]]
# 0.703117074347
# /Users/Daniel/.pyenv/versions/sandbox/lib/python3.4/site-packages/sklearn/naive_bayes.py:150: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-cbe9ce5bfe00> in <module>()
#      14 from sklearn.cross_validation import cross_val_score
#      15
# ---> 16 scores = cross_val_score(classifier, spam_base, spam_target, cv=5)
#
# NameError: name 'spam_base' is not defined
